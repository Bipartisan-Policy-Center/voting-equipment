# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib
from matplotlib import font_manager
from matplotlib import lines
import matplotlib.patheffects as pe
import os
from datawrapper import Datawrapper
dw = Datawrapper(access_token=os.environ['DATAWRAPPER_KEY'])
from lifelines import KaplanMeierFitter

# %%
# %config InlineBackend.figure_formats = ['svg']
dpi = 300
matplotlib.rcParams['figure.dpi']= dpi

pd.set_option('display.max_rows', 200)

figsize = (8, 5)
matplotlib.rcParams['figure.figsize'] = figsize

# plot parameters
# Brand Primary Colors
red = '#e43e47'
blue = '#3c608a'
black = '#000000'
dark_gray = '#333638'
light_gray = '#d3d8d6'

# Brand Secondary Colors
cyan = '#1b83c6'
dark_blue = '#1f476c'
dark_pink = '#b71d51'
pompadour = '#6f173a'
strong_red = '#b91f24'
vivid_orange = '#fcbb13'
apocalyptic_orange = '#f47521'
green_haze = '#00ad4d'

recommended_bpc_palette = [red, dark_blue, dark_gray,
                           vivid_orange, green_haze, apocalyptic_orange]
modified_bpc_palette = [red, cyan, vivid_orange, pompadour,
                        apocalyptic_orange, blue, green_haze,
                        dark_pink, strong_red, dark_blue]
bpc_monochrome_palette = [black, dark_gray, light_gray]
# i pushed green down the list for colorblindness reasons


fe = font_manager.FontEntry(
    fname= 'bpc_fonts/Redesign-3/Styrene/StyreneA-Black.otf',
    name='StyreneABlack')
font_manager.fontManager.ttflist.insert(0, fe) # or append is fine

fe = font_manager.FontEntry(
    fname= 'bpc_fonts/Redesign-3/Styrene/StyreneA-Medium.otf',
    name='StyreneAMedium')
font_manager.fontManager.ttflist.insert(0, fe) # or append is fine

fe = font_manager.FontEntry(
    fname='bpc_fonts/Redesign-3/Styrene/StyreneA-Regular.otf',
    name='StyreneARegular')
font_manager.fontManager.ttflist.insert(0, fe) # or append is fine

matplotlib.rcParams['font.family'] = 'StyreneARegular' # = 'your custom ttf font name'

ms = 5 # markersize

data_label_fontsize = 9.5

# %%
df = pd.read_csv('data/vv_capture_2025-09-15_17-34-11/cleaned_verifier_data.csv', converters={'FIPS code': str}).convert_dtypes()

# Non-VVSG equipment
non_voting_equipment = ['Paper Poll Book',
                        'Hand Counted Paper Ballots', 
                        'Commercial Electronic Poll Book',
                        'In-House Electronic Poll Book',
                        'Data Unavailable',
                        'Internet Voting: Email',
                        'Internet Voting: Web Portal',
                        'Internet Voting: Fax',
                        'Remote Ballot Marking System: Client-Side',
                        'Remote Ballot Marking System: Server-Side']

# VVSG equipment
voting_equipment = ['Ballot Marking Device', 
                            'Hand-Fed Optical Scanner',
                            'Batch-Fed Optical Scanner',
                            'DRE-Touchscreen',
                            'DRE-Push Button',
                            'DRE-Dial',
                            # 'Mechanical Lever Machine',
                            # 'Punch Card Voting System',
                            'Hybrid BMD/Tabulator',
                            'Hybrid Optical Scan/DRE',
                            'Hybrid Optical Scan/BMD']

# filter only for VVSG relevant equipment
df = df[df['Equipment Type'].isin(voting_equipment)]

# merge DRE categories
df.loc[df['Equipment Type'].str.startswith('DRE'), 'Equipment Type'] = 'DRE'
df['Manufacturer + Model'] = df['Manufacturer'] + ' ' + df['Model']
# Out:
# /var/folders/2f/3k2b0y_s79n84y37bcnb5t5h0000gn/T/ipykernel_27971/1433656129.py:1: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/vv_capture_2025-09-15_17-34-11/cleaned_verifier_data.csv', converters={'FIPS code': str}).convert_dtypes()

# %%
# add 2028 assuming no change
df26 = df[df['Year'] == 2026]

df28 = df26.copy()
df28['Year']=2028
df28['Years in Use'] = df28['Years in Use'] + 2
df28['New Equipment'] = False
df = pd.concat([df, df28], ignore_index=True)

# %%
df[df['Equipment Type']=='Hybrid BMD/Tabulator']['Model'].value_counts()
# Out:
# Model
# ExpressVote XL           92
# ExpressVote Tabulator    67
# PopulexSlate              1
# Name: count, dtype: Int64

# %%
df[df['Equipment Type']=='Hybrid Optical Scan/BMD']['Model'].value_counts()
# Out:
# Model
# ImageCast Evolution    4658
# Name: count, dtype: Int64

# %%
df[df['Equipment Type']=='Hybrid Optical Scan/DRE']['Model'].value_counts()
# Out:
# Model
# eScan A/T                 693
# ImageCast Precinct ATI      2
# Name: count, dtype: Int64

# %%
# take care of hybrids
df.loc[df['Equipment Type'].str.contains('Hybrid BMD/Tabulator'), 'Equipment Type'] = 'Ballot Marking Device'
df.loc[df['Equipment Type'].str.contains('Hybrid Optical Scan/BMD'), 'Equipment Type'] = 'Hand-Fed Optical Scanner'
df.loc[df['Equipment Type'].str.contains('Hybrid Optical Scan/DRE'), 'Equipment Type'] = 'Hand-Fed Optical Scanner'

# %%
# estimate equipment quantities from EAVS data

# load equipment-per-voter rates, computed in cost_analysis.ipynb
per_voter_rates = pd.read_csv('data/equipment_per_voter_rates_by_marking_method.csv', index_col=0)
per_voter_rates
# Out:
#                                                     dre_wo_vvpat_total  \
# Election Day Marking Method
# Ballot Marking Devices for all voters                         0.000012
# DREs with VVPAT for all voters                                0.000000
# DREs without VVPAT for all voters                             0.003137
# Hand marked paper ballots and BMDs                            0.000001
# Hand marked paper ballots and DREs without VVPAT              0.000580
# Hand marked paper ballots, BMDs and DREs with V...            0.000000
# Hand marked paper ballots, BMDs and DREs withou...            0.000230
# Hand marked paper ballots; Direct recording ass...            0.000000
#
#                                                     dre_w_vvpat_total  \
# Election Day Marking Method
# Ballot Marking Devices for all voters                        0.000035
# DREs with VVPAT for all voters                               0.002704
# DREs without VVPAT for all voters                            0.000000
# Hand marked paper ballots and BMDs                           0.000002
# Hand marked paper ballots and DREs without VVPAT             0.000000
# Hand marked paper ballots, BMDs and DREs with V...           0.000237
# Hand marked paper ballots, BMDs and DREs withou...           0.000000
# Hand marked paper ballots; Direct recording ass...           0.000000
#
#                                                     bmd_total  hand_fed_total  \
# Election Day Marking Method
# Ballot Marking Devices for all voters                0.002625        0.000488
# DREs with VVPAT for all voters                       0.000020        0.000008
# DREs without VVPAT for all voters                    0.000000        0.000002
# Hand marked paper ballots and BMDs                   0.000496        0.000517
# Hand marked paper ballots and DREs without VVPAT     0.000000        0.000601
# Hand marked paper ballots, BMDs and DREs with V...   0.000450        0.000470
# Hand marked paper ballots, BMDs and DREs withou...   0.001671        0.000246
# Hand marked paper ballots; Direct recording ass...   0.000000        0.000846
#
#                                                     batch_fed_total
# Election Day Marking Method
# Ballot Marking Devices for all voters                      0.000009
# DREs with VVPAT for all voters                             0.000007
# DREs without VVPAT for all voters                          0.000000
# Hand marked paper ballots and BMDs                         0.000012
# Hand marked paper ballots and DREs without VVPAT           0.000166
# Hand marked paper ballots, BMDs and DREs with V...         0.000018
# Hand marked paper ballots, BMDs and DREs withou...         0.000005
# Hand marked paper ballots; Direct recording ass...         0.000002

# %%
q = df.drop_duplicates(subset=['FIPS code', 'Year', 'Equipment Type'], keep='first')

# 1) Decide which per-voter-rate column each row should use
base_map = {
    "Ballot Marking Device": "bmd_total",
    "Hand-Fed Optical Scanner": "hand_fed_total",
    "Batch-Fed Optical Scanner": "batch_fed_total",
}

is_dre = q["Equipment Type"].eq("DRE")
method_lower = q["Election Day Marking Method"].fillna("").str.lower()

# DRE: default to wo_vvpat unless the method explicitly includes "with VVPAT"
with_vvpat = (q['Equipment Type']=='DRE') & q['Election Day Marking Method'].str.contains('DREs with VVPAT')

rate_col = q["Equipment Type"].map(base_map)                       # non-DRE mappings
rate_col = rate_col.mask(is_dre, "dre_wo_vvpat_total")             # DRE default
rate_col = rate_col.mask(with_vvpat, "dre_w_vvpat_total")          # DRE with VVPAT override

# 2) Reshape per_voter_rates so we can join on (Election Day Marking Method, rate_col)
pvr_long = (
    per_voter_rates
      .reset_index(names=["Election Day Marking Method"])
      .melt(id_vars="Election Day Marking Method",
            var_name="rate_col",
            value_name="per_voter_rate")
)


# 3) Merge and compute Quantity (unknowns become 0)
q_with_rates = (
    q.assign(rate_col=rate_col)
     .merge(pvr_long, on=["Election Day Marking Method", "rate_col"], how="left")
)

q_with_rates["per_voter_rate"] = q_with_rates["per_voter_rate"].fillna(0)
q_with_rates["Quantity"] = q_with_rates["Registered Voters"].fillna(0) * q_with_rates["per_voter_rate"]

# keeping only original columns + Quantity:
df = q_with_rates[q.columns.tolist() + ["Quantity"]]

# %%
# show model counts by category

# Count per Manufacturer + Model
counts = (
    df26.groupby(['Equipment Type', 'Manufacturer + Model'])
      .size()
      .reset_index(name='count')
)

# Total per Equipment Type
totals = counts.groupby('Equipment Type')['count'].sum().reset_index(name='total')

# Sort by total then breakdown counts
counts = counts.merge(totals, on='Equipment Type')
counts = counts.sort_values(['total', 'count', 'Manufacturer + Model'], ascending=[False, False, True])

# Build list with header rows inserted
rows = []
for etype, group in counts.groupby('Equipment Type', sort=False):
    total = group['total'].iloc[0]
    rows.append({'Equipment Type': f'=== {etype} (Total: {total}) ===', 'Manufacturer + Model': '', 'count': ''})
    rows.extend(group[['Equipment Type', 'Manufacturer + Model', 'count']].to_dict('records'))

# Create final DataFrame for display
final_df = pd.DataFrame(rows)
final_df
# Out:
#                                      Equipment Type  \
# 0       === Ballot Marking Device (Total: 5008) ===
# 1                             Ballot Marking Device
# 2                             Ballot Marking Device
# 3                             Ballot Marking Device
# 4                             Ballot Marking Device
# 5                             Ballot Marking Device
# 6                             Ballot Marking Device
# 7                             Ballot Marking Device
# 8                             Ballot Marking Device
# 9                             Ballot Marking Device
# 10                            Ballot Marking Device
# 11                            Ballot Marking Device
# 12                            Ballot Marking Device
# 13                            Ballot Marking Device
# 14                            Ballot Marking Device
# 15                            Ballot Marking Device
# 16                            Ballot Marking Device
# 17                            Ballot Marking Device
# 18   === Hand-Fed Optical Scanner (Total: 4347) ===
# 19                         Hand-Fed Optical Scanner
# 20                         Hand-Fed Optical Scanner
# 21                         Hand-Fed Optical Scanner
# 22                         Hand-Fed Optical Scanner
# 23                         Hand-Fed Optical Scanner
# 24                         Hand-Fed Optical Scanner
# 25                         Hand-Fed Optical Scanner
# 26                         Hand-Fed Optical Scanner
# 27                         Hand-Fed Optical Scanner
# 28                         Hand-Fed Optical Scanner
# 29                         Hand-Fed Optical Scanner
# 30                         Hand-Fed Optical Scanner
# 31  === Batch-Fed Optical Scanner (Total: 1611) ===
# 32                        Batch-Fed Optical Scanner
# 33                        Batch-Fed Optical Scanner
# 34                        Batch-Fed Optical Scanner
# 35                        Batch-Fed Optical Scanner
# 36                        Batch-Fed Optical Scanner
# 37                        Batch-Fed Optical Scanner
# 38                        Batch-Fed Optical Scanner
# 39                        Batch-Fed Optical Scanner
# 40                        Batch-Fed Optical Scanner
# 41                        Batch-Fed Optical Scanner
# 42                        Batch-Fed Optical Scanner
# 43                        Batch-Fed Optical Scanner
# 44                        Batch-Fed Optical Scanner
# 45     === Hybrid Optical Scan/BMD (Total: 938) ===
# 46                          Hybrid Optical Scan/BMD
# 47                         === DRE (Total: 399) ===
# 48                                              DRE
# 49                                              DRE
# 50                                              DRE
# 51                                              DRE
# 52                                              DRE
# 53                                              DRE
# 54                                              DRE
# 55      === Hybrid Optical Scan/DRE (Total: 77) ===
# 56                          Hybrid Optical Scan/DRE
# 57         === Hybrid BMD/Tabulator (Total: 34) ===
# 58                             Hybrid BMD/Tabulator
# 59                             Hybrid BMD/Tabulator
#
#                       Manufacturer + Model count
# 0
# 1                         ES&S ExpressVote  2681
# 2         Democracy Live OmniBallot Tablet   542
# 3                            ES&S AutoMARK   411
# 4                 Dominion ImageCast X BMD   384
# 5      Hart InterCivic Verity Touch Writer   187
# 6               Hart InterCivic Verity Duo   181
# 7                     Unisyn OpenElect FVT   176
# 8        IVS Inspire Ballot Marking System   169
# 9                 Clear Ballot ClearAccess   108
# 10                    Unisyn OpenElect OVI    66
# 11         Dominion ImageCast Precinct BMD    44
# 12                 Unisyn OpenElect OVI-VC    35
# 13                  Clear Ballot ClearMark    16
# 14                      VotingWorks VxMark     5
# 15               IVS Inspire Vote By Phone     1
# 16             Los Angeles County VSAP BMD     1
# 17                    Populex PopulexSlate     1
# 18
# 19                              ES&S DS200  2344
# 20             Dominion ImageCast Precinct   771
# 21             Hart InterCivic Verity Scan   341
# 22                              ES&S DS300   303
# 23                    Unisyn OpenElect OVO   172
# 24  MicroVote MicroVote/Chatsworth Scanner    99
# 25                    Unisyn OpenElect FVS    95
# 26                  Clear Ballot ClearCast    90
# 27           Premier (Diebold) AccuVote OS    71
# 28                      VotingWorks VxScan    48
# 29               Clear Ballot ClearCast Go     9
# 30                          ES&S Model 100     4
# 31
# 32                              ES&S DS450   482
# 33              Dominion ImageCast Central   472
# 34                              ES&S DS850   209
# 35          Hart InterCivic Verity Central   124
# 36                 Clear Ballot ClearCount    96
# 37              Hart InterCivic Ballot Now    77
# 38                   Unisyn OpenElect OVCS    71
# 39                              ES&S DS950    63
# 40               VotingWorks VxCentralScan     7
# 41              Unisyn OpenElect OVCS mini     4
# 42                          ES&S Model 650     3
# 43                              ES&S DS200     2
# 44           Los Angeles County VSAP Tally     1
# 45
# 46            Dominion ImageCast Evolution   938
# 47
# 48                Dominion ImageCast X DRE   223
# 49                      MicroVote Infinity   100
# 50                   Sequoia AVC Advantage    64
# 51                       ES&S ExpressTouch     8
# 52            Hart InterCivic Verity Touch     2
# 53                          ES&S iVotronic     1
# 54                  Hart InterCivic eSlate     1
# 55
# 56               Hart InterCivic eScan A/T    77
# 57
# 58                     ES&S ExpressVote XL    22
# 59              ES&S ExpressVote Tabulator    12

# %%
# set quantity floor of 0 (it is okay to do this because jurisdictions actually must own at least one piece of equipment to be in the VV dataset)
df['Quantity'] = df['Quantity'].clip(lower=1)
# Out:
# /var/folders/2f/3k2b0y_s79n84y37bcnb5t5h0000gn/T/ipykernel_27971/1876045910.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Quantity'] = df['Quantity'].clip(lower=1)

# %% [markdown]
# ## Histogram of equipment age (weighted by equipment counts)

# %%
bins=np.arange(0,26,2)
midpoints = (bins[:-1] + bins[1:]) // 2
g = sns.displot(data=df, row='Year', x='Years in Use', kind='hist', height=0.63, aspect=10, bins=list(bins),
                weights='Quantity', hue='Equipment Type', multiple='stack', edgecolor='white',
                palette=modified_bpc_palette, alpha=1)
g.legend.set_loc('upper right')

for ax in g.axes:
    ax = ax[0]
    ax.set_yticks(np.linspace(0, 2e5, 3))
    ax.set_xticks(midpoints)
    ax.set_xticklabels(bins[:-1], color='black')
    ax.set_xlim(0, 20)
    ax.set_yticklabels(labels=ax.get_yticklabels(), color='black')
    ax.set_ylabel(ax.title.get_text()[-4:], rotation=0, ha='right', fontname='StyreneAMedium')
    ax.set_xlabel('Years in Use', fontname='StyreneAMedium')
    ax.set_title('')  # Remove the title
    ax.get_yaxis().set_major_formatter(
        matplotlib.ticker.FuncFormatter(lambda x, _: f'{int(x/1000)}K'))


plt.subplots_adjust(hspace=0.8)

plt.savefig("figs/age_hist_over_time.png", bbox_inches='tight', dpi=300)
# Out:
# /var/folders/2f/3k2b0y_s79n84y37bcnb5t5h0000gn/T/ipykernel_27971/4288831663.py:3: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   g = sns.displot(data=df, row='Year', x='Years in Use', kind='hist', height=0.63, aspect=10, bins=list(bins),

# %%
df.pivot_table(index='Year', columns='Equipment Type', values='Quantity', aggfunc='sum', fill_value=0).reset_index().rename_axis(None, axis=1)
# Out:
#     Year  Ballot Marking Device  Batch-Fed Optical Scanner            DRE  \
# 0   2006           24393.808074                1893.571117  235532.138245
# 1   2008           29319.813806                2679.306451  192082.906502
# 2   2010           33773.870024                2563.599367  186321.602982
# 3   2012           33658.464195                2749.621288  188575.160969
# 4   2014           34743.544524                2618.436045  181876.227029
# 5   2016           47916.375278                2601.455283  176971.831221
# 6   2018           59177.201391                2340.738637  169274.111968
# 7   2020          172928.873995                2435.664619   75135.352105
# 8   2022          194461.483348                2535.536794    41579.40751
# 9   2024          210366.131854                2684.001152   29292.599214
# 10  2026          212250.026714                2682.753582   29304.406865
# 11  2028          212250.026714                2682.753582   29304.406865
#
#     Hand-Fed Optical Scanner
# 0               28839.549495
# 1               36569.708409
# 2               41478.091397
# 3               43421.921021
# 4               42634.661341
# 5               52620.167363
# 6                53004.61899
# 7               77827.392295
# 8               81338.953326
# 9               84051.744449
# 10              83183.395915
# 11              83183.395915

# %% [markdown]
# # Average age of equipment in 2026 (weighted by equipment count)

# %%
voting_df_26 = df[df["Year"] == 2026]

state_eq_len = (
    voting_df_26
    .groupby("State")
    .apply(lambda g: (g["Years in Use"] * g["Quantity"]).sum() / g["Quantity"].sum(), include_groups=False)
    .reset_index(name="Weighted Years in Use")
).sort_values(['Weighted Years in Use'], ascending=False)

state_eq_len.to_csv('data/weighted_avg_equipment_age_by_state_2026.csv', index=False)
state_eq_len.round(1).head(5)
# Out:
#                        State  Weighted Years in Use
# 19                 Louisiana                   23.8
# 38                  Oklahoma                   14.0
# 41               Puerto Rico                   13.9
# 15                   Indiana                   13.3
# 36  Northern Mariana Islands                   13.2

# %%
voting_df_26.sort_values('Years in Use', ascending=False).head(20)
# Out:
#        Year   FIPS code          State  \
# 30005  2026  2209700000      Louisiana
# 29147  2026  2201900000      Louisiana
# 29499  2026  2205100000      Louisiana
# 29719  2026  2207100000      Louisiana
# 29301  2026  2203300000      Louisiana
# 29895  2026  2208700000      Louisiana
# 28949  2026  2200100000      Louisiana
# 30269  2026  2212100000      Louisiana
# 29125  2026  2201700000      Louisiana
# 30071  2026  2210300000      Louisiana
# 19574  2026  1800500000        Indiana
# 20617  2026  1809900000        Indiana
# 61510  2026  3301769940  New Hampshire
# 59861  2026  3301150260  New Hampshire
# 59616  2026  3301129860  New Hampshire
# 59181  2026  3300933860  New Hampshire
# 19554  2026  1800300000        Indiana
# 59498  2026  3301101300  New Hampshire
# 78064  2026  4700300000      Tennessee
# 60093  2026  3301306500  New Hampshire
#
#                                   Jurisdiction  Registered Voters  \
# 30005                        St. Landry Parish              52129
# 29147                         Calcasieu Parish             113683
# 29499                         Jefferson Parish             252922
# 29719                           Orleans Parish             242175
# 29301                  East Baton Rouge Parish             263212
# 29895                       St. Bernard Parish              24546
# 28949                            Acadia Parish              35655
# 30269                  West Baton Rouge Parish              16635
# 29125                             Caddo Parish             130506
# 30071                       St. Tammany Parish             181755
# 19574                       Bartholomew County              49058
# 20617                          Marshall County              27617
# 61510   City of Somersworth (Strafford County)               7940
# 59861     City of Nashua (Hillsborough County)              56494
# 59616  Town of Goffstown (Hillsborough County)              12699
# 59181         Town of Hanover (Grafton County)               9053
# 19554                             Allen County             242146
# 59498    Town of Amherst (Hillsborough County)               9227
# 78064                           Bedford County              29325
# 60093           Town of Bow (Merrimack County)               6424
#
#                  Equipment Type       Manufacturer  \
# 30005                       DRE            Sequoia
# 29147                       DRE            Sequoia
# 29499                       DRE            Sequoia
# 29719                       DRE            Sequoia
# 29301                       DRE            Sequoia
# 29895                       DRE            Sequoia
# 28949                       DRE            Sequoia
# 30269                       DRE            Sequoia
# 29125                       DRE            Sequoia
# 30071                       DRE            Sequoia
# 19574  Hand-Fed Optical Scanner          MicroVote
# 20617  Hand-Fed Optical Scanner          MicroVote
# 61510  Hand-Fed Optical Scanner  Premier (Diebold)
# 59861  Hand-Fed Optical Scanner  Premier (Diebold)
# 59616  Hand-Fed Optical Scanner  Premier (Diebold)
# 59181  Hand-Fed Optical Scanner  Premier (Diebold)
# 19554  Hand-Fed Optical Scanner          MicroVote
# 59498  Hand-Fed Optical Scanner  Premier (Diebold)
# 78064  Hand-Fed Optical Scanner          MicroVote
# 60093  Hand-Fed Optical Scanner  Premier (Diebold)
#
#                               Model  First Year in Use  Years in Use  ...  \
# 30005                 AVC Advantage               1998            28  ...
# 29147                 AVC Advantage               1998            28  ...
# 29499                 AVC Advantage               1998            28  ...
# 29719                 AVC Advantage               1998            28  ...
# 29301                 AVC Advantage               1998            28  ...
# 29895                 AVC Advantage               1998            28  ...
# 28949                 AVC Advantage               1998            28  ...
# 30269                 AVC Advantage               1998            28  ...
# 29125                 AVC Advantage               1998            28  ...
# 30071                 AVC Advantage               1998            28  ...
# 19574  MicroVote/Chatsworth Scanner               2000            26  ...
# 20617  MicroVote/Chatsworth Scanner               2000            26  ...
# 61510                   AccuVote OS               2000            26  ...
# 59861                   AccuVote OS               2000            26  ...
# 59616                   AccuVote OS               2000            26  ...
# 59181                   AccuVote OS               2000            26  ...
# 19554  MicroVote/Chatsworth Scanner               2000            26  ...
# 59498                   AccuVote OS               2000            26  ...
# 78064  MicroVote/Chatsworth Scanner               2000            26  ...
# 60093                   AccuVote OS               2000            26  ...
#
#        Early Voting Accessible  Mail Ballot/Absentee Equipment  \
# 30005                    False                           False
# 29147                    False                           False
# 29499                    False                           False
# 29719                    False                           False
# 29301                    False                           False
# 29895                    False                           False
# 28949                    False                           False
# 30269                    False                           False
# 29125                    False                           False
# 30071                    False                           False
# 19574                    False                            True
# 20617                    False                            True
# 61510                    False                            True
# 59861                    False                            True
# 59616                    False                            True
# 59181                    False                            True
# 19554                    False                            True
# 59498                    False                            True
# 78064                    False                            True
# 60093                    False                            True
#
#        Notes on usage  Precincts         Voting Location  All Mail Ballot?  \
# 30005            <NA>         91  Assigned Polling Place             False
# 29147            <NA>        123  Assigned Polling Place             False
# 29499            <NA>        271  Assigned Polling Place             False
# 29719            <NA>        349  Assigned Polling Place             False
# 29301            <NA>        331  Assigned Polling Place             False
# 29895            <NA>         31  Assigned Polling Place             False
# 28949            <NA>         47  Assigned Polling Place             False
# 30269            <NA>         30  Assigned Polling Place             False
# 29125            <NA>        128  Assigned Polling Place             False
# 30071            <NA>        170  Assigned Polling Place             False
# 19574            <NA>         66             Vote Center             False
# 20617            <NA>         29             Vote Center             False
# 61510            <NA>          5  Assigned Polling Place             False
# 59861            <NA>          9  Assigned Polling Place             False
# 59616            <NA>          2  Assigned Polling Place             False
# 59181            <NA>          1  Assigned Polling Place             False
# 19554            <NA>        278  Assigned Polling Place             False
# 59498            <NA>          1  Assigned Polling Place             False
# 78064            <NA>         11  Assigned Polling Place             False
# 60093            <NA>          1  Assigned Polling Place             False
#
#               Election Day Marking Method      Election Day Tabulation  \
# 30005   DREs without VVPAT for all voters                          DRE
# 29147   DREs without VVPAT for all voters                          DRE
# 29499   DREs without VVPAT for all voters                          DRE
# 29719   DREs without VVPAT for all voters                          DRE
# 29301   DREs without VVPAT for all voters                          DRE
# 29895   DREs without VVPAT for all voters                          DRE
# 28949   DREs without VVPAT for all voters                          DRE
# 30269   DREs without VVPAT for all voters                          DRE
# 29125   DREs without VVPAT for all voters                          DRE
# 30071   DREs without VVPAT for all voters                          DRE
# 19574      DREs with VVPAT for all voters                          DRE
# 20617      DREs with VVPAT for all voters                          DRE
# 61510  Hand marked paper ballots and BMDs                 Optical Scan
# 59861  Hand marked paper ballots and BMDs  Hand Count and Optical Scan
# 59616  Hand marked paper ballots and BMDs  Hand Count and Optical Scan
# 59181  Hand marked paper ballots and BMDs  Hand Count and Optical Scan
# 19554      DREs with VVPAT for all voters                          DRE
# 59498  Hand marked paper ballots and BMDs  Hand Count and Optical Scan
# 78064      DREs with VVPAT for all voters                          DRE
# 60093  Hand marked paper ballots and BMDs  Hand Count and Optical Scan
#
#                          Manufacturer + Model    Quantity
# 30005                   Sequoia AVC Advantage  163.523265
# 29147                   Sequoia AVC Advantage  356.611777
# 29499                   Sequoia AVC Advantage  793.390075
# 29719                   Sequoia AVC Advantage  759.677851
# 29301                   Sequoia AVC Advantage  825.668737
# 29895                   Sequoia AVC Advantage   76.998256
# 28949                   Sequoia AVC Advantage  111.846036
# 30269                   Sequoia AVC Advantage   52.182269
# 29125                   Sequoia AVC Advantage  409.383783
# 30071                   Sequoia AVC Advantage  570.146579
# 19574  MicroVote MicroVote/Chatsworth Scanner         1.0
# 20617  MicroVote MicroVote/Chatsworth Scanner         1.0
# 61510           Premier (Diebold) AccuVote OS    4.106423
# 59861           Premier (Diebold) AccuVote OS   29.217662
# 59616           Premier (Diebold) AccuVote OS     6.56769
# 59181           Premier (Diebold) AccuVote OS    4.682046
# 19554  MicroVote MicroVote/Chatsworth Scanner     1.94646
# 59498           Premier (Diebold) AccuVote OS    4.772035
# 78064  MicroVote MicroVote/Chatsworth Scanner         1.0
# 60093           Premier (Diebold) AccuVote OS    3.322375
#
# [20 rows x 27 columns]

# %%
# of voters per piece of equipment.
voting_df_26.groupby('State')['Registered Voters'].sum().div(voting_df_26.groupby('State')['Quantity'].sum(), axis=0).sort_values(ascending=False).apply(int)
# Out:
# State
# Oregon                      7104
# Washington                  3907
# Guam                        3904
# Colorado                    3846
# Northern Mariana Islands    3650
# Alaska                      3404
# Nebraska                    3383
# Montana                     3284
# New Mexico                  3248
# South Dakota                3209
# Arizona                     3121
# Florida                     2945
# District of Columbia        2925
# Hawaii                      2924
# Minnesota                   2826
# Rhode Island                2809
# Maryland                    2725
# North Dakota                2673
# Iowa                        2650
# Michigan                    2616
# Virginia                    2542
# Illinois                    2464
# Missouri                    2433
# Alabama                     2429
# New York                    2319
# Massachusetts               2286
# Oklahoma                    2264
# Idaho                       2240
# North Carolina              2142
# Kentucky                    2096
# Mississippi                 2075
# Wyoming                     1979
# Connecticut                 1974
# Puerto Rico                 1973
# US Virgin Islands           1973
# New Hampshire               1853
# Pennsylvania                1784
# Utah                        1610
# Maine                       1545
# Kansas                      1525
# California                  1520
# Vermont                     1480
# Wisconsin                   1458
# Ohio                        1384
# Texas                       1118
# Tennessee                   1051
# Georgia                      955
# South Carolina               891
# Indiana                      891
# Arkansas                     878
# New Jersey                   803
# Delaware                     759
# Nevada                       744
# West Virginia                709
# Louisiana                    632
# dtype: int64

# %% [markdown]
# # Do larger jurisdictions have newer equipment?
# No. Analysis below.

# %%
voting_df_26
# Out:
#         Year   FIPS code                     State              Jurisdiction  \
# 10      2026  0100100000                   Alabama            Autauga County
# 21      2026  0100100000                   Alabama            Autauga County
# 32      2026  0100300000                   Alabama            Baldwin County
# 34      2026  0100300000                   Alabama            Baldwin County
# 45      2026  0100300000                   Alabama            Baldwin County
# ...      ...         ...                       ...                       ...
# 126836  2026  6900000000  Northern Mariana Islands  Northern Mariana Islands
# 126846  2026  7200000000               Puerto Rico               Puerto Rico
# 126852  2026  7200000000               Puerto Rico               Puerto Rico
# 126859  2026  7800000000         US Virgin Islands         US Virgin Islands
# 126870  2026  7800000000         US Virgin Islands         US Virgin Islands
#
#         Registered Voters             Equipment Type Manufacturer  \
# 10                  41817      Ballot Marking Device         ES&S
# 21                  41817   Hand-Fed Optical Scanner         ES&S
# 32                 181019      Ballot Marking Device         ES&S
# 34                 181019  Batch-Fed Optical Scanner         ES&S
# 45                 181019   Hand-Fed Optical Scanner         ES&S
# ...                   ...                        ...          ...
# 126836              19329  Batch-Fed Optical Scanner         ES&S
# 126846            1987317      Ballot Marking Device          IVS
# 126852            1987317   Hand-Fed Optical Scanner     Dominion
# 126859              31171      Ballot Marking Device         ES&S
# 126870              31171   Hand-Fed Optical Scanner         ES&S
#
#                         Model  First Year in Use  Years in Use  ...  \
# 10                ExpressVote               2022             4  ...
# 21                      DS200               2014            12  ...
# 32                ExpressVote               2020             6  ...
# 34                      DS450               2024             2  ...
# 45                      DS200               2014            12  ...
# ...                       ...                ...           ...  ...
# 126836                  DS450               2020             6  ...
# 126846  Inspire Vote By Phone               2008            18  ...
# 126852     ImageCast Precinct               2016            10  ...
# 126859            ExpressVote               2018             8  ...
# 126870                  DS200               2014            12  ...
#
#         Early Voting Accessible  Mail Ballot/Absentee Equipment  \
# 10                        False                           False
# 21                        False                            True
# 32                        False                           False
# 34                        False                            True
# 45                        False                           False
# ...                         ...                             ...
# 126836                    False                            True
# 126846                     True                           False
# 126852                    False                            True
# 126859                     True                           False
# 126870                    False                            True
#
#         Notes on usage  Precincts         Voting Location  All Mail Ballot?  \
# 10                <NA>         20  Assigned Polling Place             False
# 21                <NA>         20  Assigned Polling Place             False
# 32                <NA>         59  Assigned Polling Place             False
# 34                <NA>         59  Assigned Polling Place             False
# 45                <NA>         59  Assigned Polling Place             False
# ...                ...        ...                     ...               ...
# 126836            <NA>          7  Assigned Polling Place             False
# 126846            <NA>        114  Assigned Polling Place             False
# 126852            <NA>        114  Assigned Polling Place             False
# 126859            <NA>         22  Assigned Polling Place             False
# 126870            <NA>         22  Assigned Polling Place             False
#
#                Election Day Marking Method  Election Day Tabulation  \
# 10      Hand marked paper ballots and BMDs             Optical Scan
# 21      Hand marked paper ballots and BMDs             Optical Scan
# 32      Hand marked paper ballots and BMDs             Optical Scan
# 34      Hand marked paper ballots and BMDs             Optical Scan
# 45      Hand marked paper ballots and BMDs             Optical Scan
# ...                                    ...                      ...
# 126836  Hand marked paper ballots and BMDs             Optical Scan
# 126846  Hand marked paper ballots and BMDs             Optical Scan
# 126852  Hand marked paper ballots and BMDs             Optical Scan
# 126859  Hand marked paper ballots and BMDs             Optical Scan
# 126870  Hand marked paper ballots and BMDs             Optical Scan
#
#                Manufacturer + Model     Quantity
# 10                 ES&S ExpressVote    20.745371
# 21                       ES&S DS200    21.626986
# 32                 ES&S ExpressVote     89.80334
# 34                       ES&S DS450     2.186432
# 45                       ES&S DS200    93.619711
# ...                             ...          ...
# 126836                   ES&S DS450          1.0
# 126846    IVS Inspire Vote By Phone   985.905918
# 126852  Dominion ImageCast Precinct  1027.803945
# 126859             ES&S ExpressVote    15.463901
# 126870                   ES&S DS200     16.12107
#
# [12266 rows x 27 columns]

# %%
avg = (
    voting_df_26
    .groupby("FIPS code")
    .apply(lambda g: pd.Series({
        "Registered Voters": g["Registered Voters"].mean(),
        "Years in Use": np.average(g["Years in Use"], weights=g["Quantity"]),
        "Jurisdiction": g["Jurisdiction"].iloc[0],
        "State": g["State"].iloc[0],
        "Quantity": g["Quantity"].sum()
    }))
    .reset_index()
)
avg
# Out:
# /var/folders/2f/3k2b0y_s79n84y37bcnb5t5h0000gn/T/ipykernel_27971/2057775539.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: pd.Series({
#        FIPS code  Registered Voters  Years in Use              Jurisdiction  \
# 0     0100100000            41817.0      8.083226            Autauga County
# 1     0100300000           181019.0      8.979226            Baldwin County
# 2     0100500000            15697.0      8.083226            Barbour County
# 3     0100700000            14304.0      5.020806               Bibb County
# 4     0100900000            41217.0      8.083226             Blount County
# ...          ...                ...           ...                       ...
# 6367  5604500000             3833.0      6.000000             Weston County
# 6368  6600000000            62098.0      5.874241                      Guam
# 6369  6900000000            19329.0     13.244506  Northern Mariana Islands
# 6370  7200000000          1987317.0     13.916774               Puerto Rico
# 6371  7800000000            31171.0     10.041613         US Virgin Islands
#
#                          State     Quantity
# 0                      Alabama    42.372357
# 1                      Alabama   185.609482
# 2                      Alabama    15.905466
# 3                      Alabama    14.493966
# 4                      Alabama    41.764389
# ...                        ...          ...
# 6367                   Wyoming     3.883905
# 6368                      Guam    31.806754
# 6369  Northern Mariana Islands    10.589097
# 6370               Puerto Rico  2013.709863
# 6371         US Virgin Islands    31.584971
#
# [6372 rows x 6 columns]

# %%
# %config InlineBackend.figure_formats = ['png']

# Set up the plot style
axis_width = 1
sns.set_style("whitegrid", {"grid.color": ".9",
                            "font.family": "StyreneARegular",
                            'axes.spines.top': False,
                            'axes.spines.right': False,
                            'xtick.bottom': True,
                            'ytick.left': True,
                            'xtick.color': '.9',
                            'ytick.color': '.9'})
# Create the scatterplot with regression line
ax = sns.regplot(
    data=avg,
    x="Registered Voters",
    y="Years in Use",
    scatter_kws={"alpha": 0.3, 'clip_on': False, 'zorder': 10},
    line_kws={"color": blue},
    ci=95,  # Confidence interval for regression line
)
for spine in ['left', 'bottom']:
    ax.spines[spine].set_linewidth(axis_width)

plt.xlabel("# of registered voters", fontname='StyreneAMedium')
plt.ylabel("Average equipment age in 2026 (years)", fontname='StyreneAMedium')
ax.get_xaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
plt.xlim([0, 6e6])
plt.ylim([0, 24])
ax.set_xticklabels(labels=ax.get_xticklabels(), color='black')
ax.set_yticklabels(labels=ax.get_yticklabels(), color='black')
plt.tight_layout()
plt.title("Larger jurisdictions do not have newer equipment, on average.", fontname='StyreneABlack');
plt.savefig('figs/age_vs_jurisdiction_size.png', bbox_inches='tight', dpi=300)
# Out:
# /var/folders/2f/3k2b0y_s79n84y37bcnb5t5h0000gn/T/ipykernel_27971/1645927403.py:31: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels=ax.get_xticklabels(), color='black')
# /var/folders/2f/3k2b0y_s79n84y37bcnb5t5h0000gn/T/ipykernel_27971/1645927403.py:32: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(labels=ax.get_yticklabels(), color='black')

# %%
# c = dw.create_chart(title = "Larger jurisdictions do not have newer equipment, on average.",
#                     chart_type = 'd3-scatter-plot', data = avg)
# id = c['publicId']
id = 'xau9s'
dw.update_chart(id, data=avg)
print(dw.get_chart(id)['publicUrl'])
dw.display_chart(id)
# Out:
# https://datawrapper.dwcdn.net/xau9s/3/
#         <iframe
#             width="600"
#             height="478"
#             src="https://datawrapper.dwcdn.net/xau9s/3/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
avg[['Registered Voters', 'Years in Use']].to_csv('data/equipment_ages_by_registered_voters.csv')

# %% [markdown]
# # Age of equipment over time

# %%
# Compute weighted average years in use per year
filtered_voting_df = df.dropna(subset=["Years in Use", "Registered Voters", 'Quantity'])

years_in_use = (
    filtered_voting_df.groupby("Year")
    .apply(lambda x: np.average(x["Years in Use"], weights=x["Quantity"]), include_groups=False)
    .reset_index(name="Weighted Years in Use")
)

# Plot
# %config InlineBackend.figure_formats = ['svg']

sns.lineplot(data=years_in_use, x="Year", y="Weighted Years in Use", marker="o",
        linestyle="-", color=blue, linewidth=1.5)

ax = plt.gca()

# Add data labels
for i, value in enumerate(years_in_use["Weighted Years in Use"]):
    ax.text(years_in_use["Year"][i], value +0.2, f"{value:.1f}", ha="center", va="bottom",
            fontsize=data_label_fontsize, color=dark_gray,
            path_effects=[pe.withStroke(linewidth=4, foreground='white')])

# Formatting
ax.set_ylabel("Average equipment age (years)", fontname='StyreneAMedium')
ax.set_xlabel("Election year", fontname='StyreneAMedium')
ax.set_title("In 2028, voting equipment will be\nalmost as old as it has ever been.", fontname='StyreneABlack')

# Ensure x-axis ticks are formatted correctly
plt.xticks(years_in_use["Year"], rotation=0, ha="center")
ax.set_xticklabels(labels=ax.get_xticklabels(), color='black')
ax.set_yticklabels(labels=ax.get_yticklabels(), color='black')
plt.ylim(0, 12)
plt.savefig("figs/weighted_avg_years_in_use_over_time.png", bbox_inches='tight', dpi=300)
plt.show()
# Out:
# /var/folders/2f/3k2b0y_s79n84y37bcnb5t5h0000gn/T/ipykernel_27971/752024444.py:32: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(labels=ax.get_yticklabels(), color='black')

# %%
years_in_use
# Out:
#     Year  Weighted Years in Use
# 0   2006               1.986378
# 1   2008               3.710308
# 2   2010               4.988982
# 3   2012               6.776504
# 4   2014               8.451138
# 5   2016               9.300344
# 6   2018              10.078204
# 7   2020               4.930708
# 8   2022               4.883474
# 9   2024               5.670308
# 10  2026               7.304200
# 11  2028               9.304200

# %%
# c = dw.create_chart(title = "In 2028, voting equipment will be almost as old as it has ever been.",
#                     chart_type = 'd3-lines', data = years_in_use)

id = 'zsSsN'
dw.update_chart(id, data=years_in_use)
print(dw.get_chart(id)['publicUrl'])
dw.display_chart(id)
# Out:
# https://datawrapper.dwcdn.net/zsSsN/3/
#         <iframe
#             width="600"
#             height="466"
#             src="https://datawrapper.dwcdn.net/zsSsN/3/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
filtered_voting_df['Equipment Type'].value_counts()
# Out:
# Equipment Type
# Hand-Fed Optical Scanner     54295
# Ballot Marking Device        47834
# DRE                          22952
# Batch-Fed Optical Scanner    13993
# Name: count, dtype: Int64

# %%
# same as above, but with breakout by equipment type

years_in_use = (
    filtered_voting_df.groupby("Year")
    .apply(lambda x: np.average(x["Years in Use"], weights=x["Quantity"]), include_groups=False)
    .reset_index(name="Weighted Years in Use")
)


years_in_use_breakout = (
    filtered_voting_df.groupby(['Year', 'Equipment Type'])
    .apply(lambda x: np.average(x["Years in Use"], weights=x["Quantity"]), include_groups=False)
    .reset_index(name="Weighted Years in Use")
)

# Plot with seaborn
fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(ax=ax, data=years_in_use_breakout, x='Year', y='Weighted Years in Use', hue='Equipment Type', marker='o', palette=modified_bpc_palette)

ax.plot(years_in_use["Year"], years_in_use["Weighted Years in Use"], marker="o", linestyle="-", color='black', linewidth=4, alpha=0.5)

# Formatting
ax.set_ylabel("Number of Years", fontsize=10)
ax.set_xlabel("Year", fontsize=10)
ax.set_title("Average Number of Years that Equipment has Been in Use", fontsize=12)
ax.grid(axis="y", linestyle="--", alpha=0.7)

# Ensure x-axis ticks are formatted correctly
plt.xticks(years_in_use["Year"], rotation=0, ha="center")

plt.ylim(0, 50)

# try to understand this better. DREs got younger in 2020 because old ones were decommissioned?
# Out:
# /var/folders/2f/3k2b0y_s79n84y37bcnb5t5h0000gn/T/ipykernel_27971/2302646230.py:18: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sns.lineplot(ax=ax, data=years_in_use_breakout, x='Year', y='Weighted Years in Use', hue='Equipment Type', marker='o', palette=modified_bpc_palette)
# (0.0, 50.0)

# %%
# Split out just the rows with New Equipment = True
new_eq = df[df['New Equipment'] == True].copy()

# Create a shifted Year column for lookup
new_eq['Prev Year'] = new_eq['Year'] - 2

# Merge with the original dataframe to find matches from two years earlier
merged = pd.merge(
    new_eq,
    df,
    left_on=['State', 'Jurisdiction', 'Model', 'Prev Year'],
    right_on=['State', 'Jurisdiction', 'Model', 'Year'],
    suffixes=('_new', '_prev')
)

# Optional: select only columns of interest
result = merged[[
    'State', 'Jurisdiction', 'Model',
    'Year_prev', 'New Equipment_prev',
    'Year_new', 'New Equipment_new'
]]

# Sort or inspect
result = result.sort_values(by=['State', 'Jurisdiction', 'Model', 'Year_new'])

# %% [markdown]
# ## Compare age of current equipment to typical age at retirement (weighted by quantity)

# %%
reference_year = 2028

# Function to calculate weighted average and weighted std
def weighted_stats(group):
    weights = group["Quantity"]
    values = group["Years in Use"]
    
    # Weighted average
    avg = np.average(values, weights=weights)
    
    # Weighted standard deviation
    variance = np.average((values - avg)**2, weights=weights)
    std_dev = np.sqrt(variance)

    N_equipment = sum(weights)
    N_rows = len(weights)
    
    return pd.Series({
        "Weighted Avg Age": avg,
        "Weighted Std Age": std_dev,
        "N Equipment": N_equipment,
        "N Rows": N_rows
    })



# Apply function by Equipment Type
age_at_retirement = filtered_voting_df[filtered_voting_df['Final Year in Use']==True].groupby("Equipment Type").apply(weighted_stats, include_groups=False).reset_index()


filtered_voting_df[filtered_voting_df['Final Year in Use']==True].groupby("Equipment Type").apply(weighted_stats, include_groups=False).reset_index()


# View result
age_at_retirement

current_age = filtered_voting_df[filtered_voting_df['Year'] == reference_year].groupby("Equipment Type").apply(weighted_stats, include_groups=False).reset_index()

retirement_df = pd.merge(current_age, age_at_retirement, on='Equipment Type', how='left', suffixes=(' Current', ' At Retirement'))
retirement_df = retirement_df.loc[[2, 0, 1, 3]].reset_index(drop=True)
retirement_df.round(1)
# Out:
#               Equipment Type  Weighted Avg Age Current  \
# 0                        DRE                      18.0
# 1      Ballot Marking Device                       8.2
# 2  Batch-Fed Optical Scanner                       8.7
# 3   Hand-Fed Optical Scanner                       9.0
#
#    Weighted Std Age Current  N Equipment Current  N Rows Current  \
# 0                       8.1              29304.4           335.0
# 1                       3.0             212250.0          5031.0
# 2                       3.0               2682.8          1558.0
# 3                       4.1              83182.4          5341.0
#
#    Weighted Avg Age At Retirement  Weighted Std Age At Retirement  \
# 0                             9.8                             6.1
# 1                             9.1                             4.9
# 2                             9.2                             4.8
# 3                             9.7                             5.2
#
#    N Equipment At Retirement  N Rows At Retirement
# 0                   297403.5                4313.0
# 1                    37526.3                3545.0
# 2                     3680.3                1300.0
# 3                    57608.0                6004.0

# %%
np.average(filtered_voting_df[filtered_voting_df['Year'] == reference_year]['Years in Use'],
           weights=filtered_voting_df[filtered_voting_df['Year'] == reference_year]['Quantity'])

# average current equipment age
# Out:
# np.float64(9.304200132742505)

# %%
total_weighted_avg = np.average(retirement_df["Weighted Avg Age At Retirement"], 
                                weights=retirement_df["N Equipment At Retirement"])

print(total_weighted_avg) # average overall retirement age
# Out:
# 9.70172782452438

# %%
retirement_df['delta'] = retirement_df['Weighted Avg Age Current'] - retirement_df['Weighted Avg Age At Retirement']

# %%
fig, ax = plt.subplots()
y = np.arange(len(retirement_df))

# Plot current age
ax.errorbar(retirement_df['Weighted Avg Age Current'], y, xerr=retirement_df['Weighted Std Age Current'],
            fmt='o', color=cyan, label=f'Age in {reference_year} (mean +- std)', capsize=3,
            linewidth=1.5)

# Annotate current age
for i, row in retirement_df.iterrows():
    label = f"{row['Weighted Avg Age Current']:.1f}y (n={int(row['N Rows Current'])})"
    ax.text(row['Weighted Avg Age Current'] - 0.1, y[i] - 0.1, label, color=cyan, fontsize=8)

# Plot retirement age
for i, row in retirement_df.iterrows():
    if pd.notnull(row['Weighted Avg Age At Retirement']):
        label = 'Historical retirement age' if i == 0 else ''
        ax.errorbar(row['Weighted Avg Age At Retirement'], y[i] + 0.15,
                    xerr=row['Weighted Std Age At Retirement'], fmt='o', label=label,
                    color=red, capsize=3)

# Annotate retirement age
for i, row in retirement_df.iterrows():
    label = f"{row['Weighted Avg Age At Retirement']:.1f}y (n={int(row['N Rows At Retirement'])})"
    ax.text(row['Weighted Avg Age At Retirement'] - 0.1, y[i] + 0.35, label, color=red, fontsize=8)


# Formatting
ax.set_yticks(y)
ax.set_yticklabels(retirement_df['Equipment Type'], color='black')
ax.set_xticklabels(ax.get_xticklabels(), color='black')
ax.set_xlim([0, 29])
ax.invert_yaxis()  # So first row is on top
ax.set_xlabel('Years', fontname='StyreneAMedium')
ax.set_ylabel('Equipment Type', fontname='StyreneAMedium')
ax.set_ylim([3.5, -1])
ax.set_title('Voting equipment is approaching its typical retirement age.', fontname='StyreneABlack')
ax.grid(True, axis='x')
ax.grid(False, axis='y')
plt.legend(loc='upper right')
plt.tight_layout()
plt.savefig('figs/avg_age_and_retirement_age.png', bbox_inches='tight', dpi=300)

# NOTE THAT DOTS INDICATE DATA POINTS, NOT QUANTITIES
# Out:
# /var/folders/2f/3k2b0y_s79n84y37bcnb5t5h0000gn/T/ipykernel_27971/1403842271.py:31: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), color='black')

# %%
fig, ax = plt.subplots()

bar_width = 0.56
x = np.arange(len(retirement_df))

# Plot bars
# age_bars = ax.barh(x - bar_width/2, retirement_df["Weighted Avg Age Current"], height=bar_width, label="Age in 2026",
#                    color=lightgray)
# retirement_bars = ax.barh(x, retirement_df["Weighted Avg Age At Retirement"], height=bar_width, label="Retirement Age",
#                           color=lightblue)

for i, row in retirement_df.iterrows():
    # Arrow for "Age in 2026" (gray)
    arrow = ax.arrow(
        0,                             # start x
        i,                             # start y
        row["Weighted Avg Age Current"],  # length in x direction
        0,                             # no vertical displacement
        width=bar_width * 0.5,         # "fatness" of shaft
        head_width=bar_width * 0.7,    # arrowhead width
        head_length=1,                 # arrowhead length in data coords
        fc=light_gray, ec=light_gray,
        length_includes_head=True,
        label=f'Age in {reference_year}' #if i == 0 else None
    )
    
    # Arrow for "Retirement Age" (blue)
    # ax.arrow(
    #     0,
    #     i + bar_width/2,
    #     row["Weighted Avg Age At Retirement"],
    #     0,
    #     width=bar_width * 0.8,
    #     head_width=bar_width * 1.2,
    #     head_length=2,
    #     fc=lightblue, ec=lightblue,
    #     length_includes_head=True
    # )


ax.vlines(
    x=retirement_df["Weighted Avg Age At Retirement"],  # x-position of the line
    ymin=x - bar_width/2,  # bottom of the line
    ymax=x + bar_width/2,  # top of the line
    color=red,
    label="Typical retirement age",
    linewidth=3
)

# Annotate differences
for i, row in retirement_df.iterrows():
    # Determine which is smaller to anchor the label
    end_x  = row["Weighted Avg Age Current"]
    y = i

    delta = row["Weighted Avg Age Current"] - row["Weighted Avg Age At Retirement"]

    if delta < 0:
        color = 'black'
    else:
        color = red
    
    ax.annotate(
        f"{abs(delta):.1f} years {'past' if delta > 0 else 'until'} retirement age",
        xy=(end_x-0.6, y),
        ha='right', va='center',
        fontsize=8,
        color=color,
        fontname='StyreneAMedium',
        # bbox=dict(boxstyle="round,pad=0.2", edgecolor='gray', facecolor='white', alpha=0.7)
    )

vertical_line = lines.Line2D([], [], color=red, marker='|', linestyle='None',
                          markersize=10, markeredgewidth=1.5, label='Typical retirement age')



# Formatting
ax.set_yticks(x)
yticklabels = retirement_df["Equipment Type"]
yticklabels[0] = 'Direct Recording Electronic Machine'

ax.set_yticklabels(yticklabels, color='black')
# ax.set_yticklabels(retirement_df["Equipment Type"], color='black')
ax.set_xlim([0, 18])
ax.set_xticklabels(labels=ax.get_xticklabels(), color='black')
ax.invert_yaxis()
ax.set_xlabel("Average equipment age (years)", fontname='StyreneAMedium')
ax.set_ylabel("Equipment type", fontname='StyreneAMedium')
ax.set_title("Voting equipment is approaching its typical retirement age.", fontname='StyreneABlack')



ax.legend(handles=[arrow, vertical_line], loc='upper left',framealpha=0.95)
ax.grid(False, axis='y')
ax.grid(True, axis='x')

plt.tight_layout()
plt.savefig('figs/avg_age_and_retirement_age_small.png', bbox_inches='tight', dpi=300)
# Out:
# /var/folders/2f/3k2b0y_s79n84y37bcnb5t5h0000gn/T/ipykernel_27971/4100364821.py:86: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels=ax.get_xticklabels(), color='black')

# %%
data = retirement_df[['Equipment Type', 'Weighted Avg Age Current', 'Weighted Avg Age At Retirement', 'delta']]
# dw.create_chart("Voting equipment is approaching its typical retirement age.", chart_type='d3-bars', data=data)
id = 'z4cjK'
dw.update_chart(id, data=data)
print(dw.get_chart(id)['publicUrl'])
dw.publish_chart(id)
dw.display_chart(id)
# Out:
# https://datawrapper.dwcdn.net/z4cjK/1/
#         <iframe
#             width="600"
#             height="351"
#             src="https://datawrapper.dwcdn.net/z4cjK/2/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # New equipment acquisitions

# %%
# Group by year and equipment type, summing Quantity instead of row count
df_grouped = (
    df[(df['New Equipment'])]
    .groupby(['Year', 'Equipment Type'])['Quantity']
    .sum()
    .reset_index(name='Quantity')
)

# palette = [lightblue, red, mustard, blue, lightgray, pink, purple, darkblue]

ax = sns.lineplot(
    data=df_grouped,
    x='Year', y='Quantity',
    hue='Equipment Type',
    marker='o', linewidth=1.5,
    palette=modified_bpc_palette,
    hue_order=[
        'Ballot Marking Device',
        'Hand-Fed Optical Scanner',
        'Batch-Fed Optical Scanner',
        'DRE',
    ],
    clip_on=False,
    zorder=10
)


ax.legend(
    title="Equipment type",
    title_fontproperties={'family': 'StyreneAMedium', 'size': 10},
    fontsize=9,
    loc='upper center'

)
ax.set_title('New equipment acquisitions have slowed.', fontname='StyreneABlack')
ax.set_xlabel('Election year', fontname='StyreneAMedium')
ax.set_ylabel('# of new voting machines', fontname='StyreneAMedium')
ax.set_xticks(sorted(df['Year'].unique()))
ax.set_xticklabels(labels=plt.gca().get_xticklabels(), color='black')
ax.set_xlim([2006, 2026])
ax.set_ylim([0, 150e3])
ax.set_yticklabels(labels=plt.gca().get_yticklabels(), color='black')
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, _: f'{int(x/1000)}K'))
plt.grid(True)
plt.tight_layout()
plt.savefig('figs/new_equipment_acquisitions_by_type.png', bbox_inches='tight', dpi=300)

# lots of states (GA and SC) and counties (in CA and TX) went BMD for all in 2020.
# Out:
# /var/folders/2f/3k2b0y_s79n84y37bcnb5t5h0000gn/T/ipykernel_27971/2625171264.py:11: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   ax = sns.lineplot(
# /var/folders/2f/3k2b0y_s79n84y37bcnb5t5h0000gn/T/ipykernel_27971/2625171264.py:42: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(labels=plt.gca().get_yticklabels(), color='black')

# %%
order = ['Year', 'Ballot Marking Device', 'Hand-Fed Optical Scanner', 'Batch-Fed Optical Scanner', 'DRE']
pivot = df_grouped.pivot(index="Year", columns="Equipment Type", values="Quantity").reset_index().rename_axis(None, axis=1)[order]
pivot
# Out:
#     Year  Ballot Marking Device  Hand-Fed Optical Scanner  \
# 0   2006           22452.008241              12715.220109
# 1   2008            5290.364121               6502.848496
# 2   2010            2782.561533               6627.793394
# 3   2012              655.34214                2633.23566
# 4   2014            2389.630028               5535.533182
# 5   2016           13773.362902              10769.615345
# 6   2018           19269.476251              11200.394102
# 7   2020          120280.269386              28438.862337
# 8   2022           31100.619345               8680.250959
# 9   2024            9699.634107              10799.096297
# 10  2026            4846.257398               4284.282393
#
#     Batch-Fed Optical Scanner            DRE
# 0                   785.03391  117310.231388
# 1                  323.285983    1006.712533
# 2                   98.271956   15822.684883
# 3                  249.273459     359.489894
# 4                   150.75268     334.749014
# 5                  509.134951      907.56716
# 6                  493.242429     8428.66562
# 7                 1242.864945    5575.346173
# 8                  210.245095    2841.155576
# 9                  248.543571            5.0
# 10                  62.917844            1.0

# %%
# dw.create_chart("New equipment acquisitions have slowed.", chart_type='d3-lines', data=pivot)
id = 'sTtDw'
# dw.update_chart(chart_id=id, data=pivot)
print(dw.get_chart(id)['publicUrl'])
dw.publish_chart(id)
dw.display_chart(id)
# Out:
# https://datawrapper.dwcdn.net/sTtDw/15/
#         <iframe
#             width="600"
#             height="558"
#             src="https://datawrapper.dwcdn.net/sTtDw/16/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# batch-fed only
ax = sns.lineplot(
    data=df_grouped[df_grouped['Equipment Type']=='Batch-Fed Optical Scanner'],
    x='Year', y='Quantity',
    marker='o', linewidth=1.5,
    clip_on=False,
    zorder=10
)
ax.set_xticks(sorted(df['Year'].unique()))
ax.set_xticklabels(labels=plt.gca().get_xticklabels(), color='black')
ax.set_xlim([2006, 2026])
# Out:
# (2006.0, 2026.0)

# %% [markdown]
# ## Survival analysis

# %%
df26 = df[df['Year'] == 2026].copy()
retired = df[df['Final Year in Use']]

all = pd.concat([df26, retired])
all.dropna(subset=['Final Year in Use', 'Years in Use', 'Registered Voters', 'Equipment Type'], inplace=True)

# %%
t = sum(all['Final Year in Use']==True)
f = sum(all['Final Year in Use']==False)
print(f'While most of the Verified Voting dataset (which goes back to 2006) consists of equipment that was retired before 2026, a substantial portion, ({f/(t+f)*100:.1f}%) are expected to be in use in 2026.')
# Out:
# While most of the Verified Voting dataset (which goes back to 2006) consists of equipment that was retired before 2026, a substantial portion, (44.7%) are expected to be in use in 2026.

# %%
kmf = KaplanMeierFitter()
kmf.fit(all['Years in Use'], event_observed=all['Final Year in Use'], weights=all['Quantity'])
kmf.survival_function_.plot()
plt.title('Survival function of voting equipment');
# Out:
# /Users/will/Repos/voting-equipment/.venv/lib/python3.13/site-packages/lifelines/fitters/kaplan_meier_fitter.py:338: StatisticalWarning: It looks like your weights are not integers, possibly propensity scores then?
#   It's important to know that the naive variance estimates of the coefficients are biased. Instead use Monte Carlo to
#   estimate the variances. See paper "Variance estimation when using inverse probability of treatment weighting (IPTW) with survival analysis"
#   or "Adjusted Kaplan-Meier estimator and log-rank test with inverse probability of treatment weighting for survival data."
#
#   warnings.warn(

# %%
kmf.plot_survival_function()
# Out:
# <Axes: xlabel='timeline'>

# %%
time = kmf.survival_function_.index
survival_prob = kmf.survival_function_.KM_estimate

# %%
from scipy.interpolate import interp1d

survival_func = interp1d(time, survival_prob, kind="linear", bounds_error=False, fill_value=(1.0, 0.0))
def hazard_func(t, survival_func, delta_time = 2):
    """
    Returns the hazard rate at time t; the probability of replacement at time t given survival until time t.
    """
    t = np.asarray(t)
    s_t = survival_func(t)
    s_t_plus = survival_func(t + delta_time)
    
    # Avoid division by zero by setting hazard to 0 where survival is 0
    with np.errstate(divide='ignore', invalid='ignore'):
        hazard = (s_t - s_t_plus) / s_t
        hazard = np.where(s_t == 0, 0.0, hazard)
    
    return hazard

hazard_func(range(0,40,2), survival_func, delta_time=2)
# Out:
# array([0.02887768, 0.05925938, 0.05219037, 0.05858875, 0.12437831,
#        0.3368823 , 0.32178637, 0.41301624, 0.28576881, 0.0926737 ,
#        0.60349982, 0.02715563, 0.00189212, 0.        , 0.97980826,
#        0.18658154, 0.33333333, 0.5       , 1.        , 1.        ])

# %%
rng = np.random.default_rng(42)  # reproducible

start_year = 2028  # first year that equipment starts being simulated for possible replacement # think about doing with 2026
end_year = 2042
delta_time = 2
years = list(range(start_year, end_year + 1, delta_time))

simulation_df = df26.copy()
simulation_df.dropna(subset='First Year in Use', inplace=True)

# Track units, not rows
simulation_df["Remaining Quantity"] = simulation_df["Quantity"].fillna(0).astype(int).clip(lower=0)
simulation_df["First Full Replace Year"] = pd.Series([None] * len(simulation_df), index=simulation_df.index)

# We'll accumulate replaced units per year here
replaced_units_per_year = {y: 0 for y in years}

for year in years:
    # Years in use for hazard calc
    simulation_df["Simulated Years in Use"] = year - simulation_df["First Year in Use"]

    # Only rows that still have units left
    mask_active = simulation_df["Remaining Quantity"] > 0
    active = simulation_df.loc[mask_active]

    if not active.empty:
        # Hazard per row for this step; ensure it's in [0,1]
        hazard = np.clip(hazard_func(
            active["Simulated Years in Use"],
            survival_func,
            delta_time=delta_time
        ), a_min=0, a_max=1)

        # Draw number of units replaced from remaining units (binomial)
        remaining_units = active["Remaining Quantity"].to_numpy()
        replaced_units = rng.binomial(n=remaining_units, p=hazard)

        # Write back
        simulation_df.loc[active.index, "Remaining Quantity"] = remaining_units - replaced_units

        # Tally replaced units this year
        replaced_units_per_year[year] += int(replaced_units.sum())

        # For rows that just hit zero, mark the first year they were fully replaced
        just_zero = (remaining_units > 0) & (remaining_units - replaced_units == 0)
        idx_just_zero = active.index[just_zero]
        # only fill if not already set
        not_set = simulation_df.loc[idx_just_zero, "First Full Replace Year"].isna()
        simulation_df.loc[idx_just_zero[not_set], "First Full Replace Year"] = year

# --- Build cumulative percentage replaced by units ---
total_units_2026 = simulation_df["Quantity"].fillna(0).clip(lower=0).sum()

cumulative_replacement_units = pd.Series(replaced_units_per_year).sort_index().cumsum()

# Optionally add a baseline zero at 2026 for the plot context
cumulative_replacement_units.loc[2026] = 0
cumulative_replacement_units = cumulative_replacement_units.sort_index()

cumulative_replacement_proportion = cumulative_replacement_units / max(total_units_2026, 1)

# --- Plot ---
axis_width = 1
sns.set_style("whitegrid", {"grid.color": ".9",
                            "font.family": "StyreneARegular",
                            'axes.spines.top': False,
                            'axes.spines.right': False,
                            'xtick.bottom': True,
                            'ytick.left': True,
                            'xtick.color': '.9',
                            'ytick.color': '.9'})

sns.lineplot(data=cumulative_replacement_proportion,
             marker='o', clip_on=False, zorder=10)

plt.grid(True)
plt.xlabel('Year', fontname='StyreneAMedium')
plt.title('Most voting equipment\ndeployed in 2026 will be replaced by 2032.', fontname='StyreneABlack')

plt.grid(True)
plt.ylabel('Percentage of 2026-deployed equipment replaced', fontname='StyreneAMedium')

ax = plt.gca()
ax.set_xticklabels(labels=ax.get_xticklabels(), color='black')
ax.set_yticklabels(labels=ax.get_yticklabels(), color='black')
plt.ylim(0, 1)
plt.yticks([0, 0.25, 0.5, 0.75, 1], ['0%', '25%', '50%', '75%', '100%']);
plt.savefig('figs/replacement_simulation_2.png', bbox_inches='tight', dpi=dpi)
# Out:
# /var/folders/2f/3k2b0y_s79n84y37bcnb5t5h0000gn/T/ipykernel_27971/2052847315.py:84: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels=ax.get_xticklabels(), color='black')
# /var/folders/2f/3k2b0y_s79n84y37bcnb5t5h0000gn/T/ipykernel_27971/2052847315.py:85: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(labels=ax.get_yticklabels(), color='black')

# %%
data = pd.DataFrame((cumulative_replacement_proportion*100).reset_index().rename(columns={"index": "Year", 0: "Percentage of 2026-deployed equipment replaced"}))
# c = dw.create_chart('Most voting equipment deployed in 2026 will be replaced by 2032.', chart_type='d3-lines', data=data)
id = '4qnzp'
print(dw.get_chart(id)['publicUrl'])

# dw.update_chart(id, data=data)
dw.publish_chart(id)
dw.display_chart(id)
# Out:
# https://datawrapper.dwcdn.net/4qnzp/11/
#         <iframe
#             width="600"
#             height="492"
#             src="https://datawrapper.dwcdn.net/4qnzp/12/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
pd.DataFrame(cumulative_replacement_proportion*100)
# Out:
#               0
# 2026   0.000000
# 2028  15.508541
# 2030  37.379255
# 2032  54.457647
# 2034  71.959043
# 2036  80.919717
# 2038  85.640571
# 2040  90.931641
# 2042  92.739108
